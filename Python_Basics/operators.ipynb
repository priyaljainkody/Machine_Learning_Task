# %%
x = 1.1+2.2
x
# Out:
# 3.3000000000000003

# %%
x==3.3
# Out:
# False

# %%
x = 1.1+2.2
x == 3.3
# Out:
# False

# %%
[5, 6, 7] > [7, 5, 6]
# Out:
# False

# %%
0 and []
# Out:
# 0

# %%
def f(arg):
    print(f" -> f({arg} = {arg}")
    return arg
f(0) or f(False) or f(2) or f(3)
# Out:
#  -> f(0 = 0
#  -> f(False = False
#  -> f(2 = 2
# 2

# %%
country = ""
default_country = "Canada"
country or default_country
# Out:
# 'Canada'

# %%
x = 10
y = 10
x is y
# Out:
# True

# %%
x = 300 
y = 300 
x is y
# Out:
# False

# %%
total = 10
total $= total + 5
total
# Out:
#   Cell In[24], line 2
#     total $= total + 5
#           ^
# SyntaxError: invalid syntax

# %%
1//2
# Out:
# 0

# %%
1//2+1
# Out:
# 1

# %%
~12
# Out:
# -13

# %%
18%48
# Out:
# 18
