# %%
from time import sleep
from threading import *
class Hello(Thread):
    def run(self):
        for i in range(5):
            print("helloo")
            sleep(1)

class Hi(Thread):
    def run(self):
        for i in range(5):
            print("hi")
            sleep(1)

t1 = Hello()
t2 = Hi()
t1.start()
sleep(0.2)
t2.start()
t1.join()
t2.join()
print("bye")
# Out:
# helloo
# hi
# helloo
# hi
# helloo
# hi
# helloo
# hi
# helloo
# hi
# bye

# %%
import threading
def cube(num):
    print(f"cube:  {num*num*num}")
def sqaure(num):
    print(f"square:  {num*num}")

t1 = threading.Thread(target = cube, args=(10,))
t2 = threading.Thread(target = sqaure, args=(10,))

t1.start()
t2.start()

t1.join()
t2.join()

print("Done!")
# Out:
# cube:  1000
# square:  100
# Done!

# %%
import threading
import os

def task1():
    print(f"Task 1 assigned to thread:{threading.current_thread().name}")
    print("ID of process running task 1: {}".format(os.getpid()))
    # print(f"task1 ID: {os.getpid}")

def task2():
    print("Task 2 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 2: {}".format(os.getpid()))

if __name__ == "__main__":

    print("ID of process running main program: {}".format(os.getpid()))

    print("Main thread name: {}".format(threading.current_thread().name))

    t1 = threading.Thread(target=task1, name='t1')
    t2 = threading.Thread(target=task2, name='t2')

    t1.start()
    t2.start()

    t1.join()
    t2.join()
# Out:
# ID of process running main program: 6472
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 6472
# Task 2 assigned to thread: t2
# ID of process running task 2: 6472

# %%
import threading
import os

def task1():
    print(f"Task 1 assigned to thread:{threading.current_thread().name}")
    print("ID of process running task 1: {}".format(os.getpid()))
    # print(f"task1 ID: {os.getpid}")

def task2():
    print("Task 2 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 2: {}".format(os.getpid()))

if __name__ == "__main__":

    print("ID of process running main program: {}".format(os.getpid()))

    print("Main thread name: {}".format(threading.current_thread().name))

    t1 = threading.Thread(target=task1, name='t1')
    t2 = threading.Thread(target=task2, name='t2')

    t1.start()
    t2.start()

    t1.join()
    t2.join()
# Out:
# ID of process running main program: 15044
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 15044
# Task 2 assigned to thread: t2
# ID of process running task 2: 15044

# %%
import threading
import os

def task1():
    print("Task 1 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 1: {}".format(os.getpid()))
def task2():
    print("Task 2 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 2: {}".format(os.getpid()))

if __name__ == "__main__":
    print("ID of process running main program: {}".format(os.getpid()))
    print("Main thread name: {}".format(threading.current_thread().name))

    abc = threading.Thread(target=task1, name="t1")
    abc1 = threading.Thread(target=task2, name='abc1')

    abc.start()
    abc1.start()

    abc.join()
    abc1.join()
# Out:
# ID of process running main program: 15044
# Main thread name: MainThread
# Task 1 assigned to thread: t1
# ID of process running task 1: 15044
# Task 2 assigned to thread: abc1
# ID of process running task 2: 15044

# %%
import threading
import os

def task1():
    print("Task 1 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 1: {}".format(os.getpid()))
def task2():
    print("Task 2 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 2: {}".format(os.getpid()))

if __name__ == "__main__":
    print("ID of process running main program: {}".format(os.getpid()))
    print("Main thread name: {}".format(threading.current_thread().name))

    abc = threading.Thread(target=task1, name="abc")
    abc1 = threading.Thread(target=task2, name='abc1')

    abc.start()
    abc1.start()

    abc.join()
    abc1.join()
# Out:
# ID of process running main program: 15320
# Main thread name: MainThread
# Task 1 assigned to thread: abc
# ID of process running task 1: 15320
# Task 2 assigned to thread: abc1
# ID of process running task 2: 15320
# ID of process running main program: 15320
# Main thread name: MainThread
# Task 1 assigned to thread: abc
# ID of process running task 1: 15320
# Task 2 assigned to thread: abc1
# ID of process running task 2: 15320
# ID of process running main program: 15320
# Main thread name: MainThread
# Task 1 assigned to thread: abc
# ID of process running task 1: 15320
# Task 2 assigned to thread: abc1
# ID of process running task 2: 15320
# ID of process running main program: 15320
# Main thread name: MainThread
# Task 1 assigned to thread: abc
# ID of process running task 1: 15320
# Task 2 assigned to thread: abc1
# ID of process running task 2: 15320
# ID of process running main program: 15320
# Main thread name: MainThread
# Task 1 assigned to thread: abc
# ...

# %%
import threading
import os

def task1():
    print(f"Task 1 assigned to thread:{threading.current_thread().name}")
    print("ID of process running task 1: {}".format(os.getpid()))
    # print(f"task1 ID: {os.getpid}")

def task2():
    print("Task 2 assigned to thread: {}".format(threading.current_thread().name))
    print("ID of process running task 2: {}".format(os.getpid()))

if __name__ == "__main__":

    print("ID of process running main program: {}".format(os.getpid()))

    print("Main thread name: {}".format(threading.current_thread().name))

    t1 = threading.Thread(target=task1, name='t1')
    t2 = threading.Thread(target=task2, name='t2')

    t1.start()
    t2.start()

    t1.join()
    t2.join()
# Out:
# ID of process running main program: 18816
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 18816
# Task 2 assigned to thread: t2
# ID of process running task 2: 18816
# ID of process running main program: 18816
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 18816
# Task 2 assigned to thread: t2
# ID of process running task 2: 18816
# ID of process running main program: 18816
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 18816
# Task 2 assigned to thread: t2
# ID of process running task 2: 18816
# ID of process running main program: 18816
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 18816
# Task 2 assigned to thread: t2
# ID of process running task 2: 18816
# ID of process running main program: 18816
# Main thread name: MainThread
# Task 1 assigned to thread:t1
# ID of process running task 1: 18816
# ...

# %%
import time 
def calc_square(numbers):
    print("calculate sqaure: ")
    for n in numbers:
        time.sleep(3)
        print('square: ', n*n)

def calc_cube(numbers):
    print("calculate cube: ")
    for n in numbers:
        time.sleep(3)
        print('cube: ', n*n*n)

arr = [2,3,8,9]
t = time.time()
calc_square(arr)
calc_cube(arr)
print("time it took: ", time.time() - t)
# Out:
# calculate sqaure:
# square:  4
# square:  9
# square:  64
# square:  81
# calculate cube:
# cube:  8
# cube:  27
# cube:  512
# cube:  729
# time it took:  24.00948452949524

# %%
import time
import threading 
def calc_square(numbers):
    # print("debug 1")
    print("calculate sqaure: ")
    for n in numbers:
        t = time.time()
        time.sleep(3)
        print('square: ', n*n)
        print("time it took: ", time.time() - t)

def calc_cube(numbers):
    # print("debug 2")
    print("calculate cube: ")
    for n in numbers:
        time.sleep(3)
        print('cube: ', n*n*n)

arr = [2,3,8,9]
t = time.time()
t1 = threading.Thread(target=calc_square, args = (arr,))
t2 = threading.Thread(target=calc_cube, args = (arr,))
t1.start()
t2.start()

t1.join()
t2.join()
print("time it took: ", time.time() - t)
# Out:
# calculate sqaure:
# calculate cube:
# square:  4
# time it took:  3.0015361309051514
# cube:  8
# square:  9
# time it took:  3.000319004058838
# cube:  27
# square:  64
# time it took:  3.0009920597076416
# cube:  512
# square:  81
# time it took:  3.0021719932556152
# cube:  729
# time it took:  12.008482694625854

# %%
import time 
import multiprocessing

def calc_square(numbers):
    print("calculate sqaure: ")
    for n in numbers:
        # time.sleep(5)
        print('square: ' + str(n*n))

def calc_cube(numbers):
    print("calculate cube: ")
    for n in numbers:
        # time.sleep(5)
        print('cube: ' + str(n*n*n))
        
if __name__ == "__main__":
    arr = [2,3,8,9]
    p1 = multiprocessing.Process(target=calc_square, args = (arr,))
    p2 = multiprocessing.Process(target=calc_cube, args = (arr,))

    p1.start()
    p2.start()

    p1.join()
    p2.join()

# %%
# importing the multiprocessing module
import multiprocessing

def print_cube(num):
    """
    function to print cube of given num
    """
    print("Cube: {}".format(num * num * num))

def print_square(num):
    """
    function to print square of given num
    """
    print("Square: {}".format(num * num))

if __name__ == "__main__":
    # creating processes
    p1 = multiprocessing.Process(target=print_square, args=(10, ))
    p2 = multiprocessing.Process(target=print_cube, args=(10, ))

    # starting process 1
    p1.start()
    # starting process 2
    p2.start()

    # wait until process 1 is finished
    p1.join()
    # wait until process 2 is finished
    p2.join()

    # both processes finished
    print("Done!")
# Out:
# Done!

# %%
# SuperFastPython.com
# example of executing a target task function in a separate thread
from time import sleep
from threading import Thread
 
# a simple task that blocks for a moment and prints a message
def task():
    # block for a moment
    # sleep(1)
    # display a message
    print('This is coming from another thread')
 
# create and configure a new thread to run a function
thread = Thread(target=task)
# start the task in a new thread
thread.start()
# display a message
print('Waiting for the new thread to finish...')
print("it is what it is")
# wait for the task to complete
thread.join()
# Out:
# This is coming from another thread
# Waiting for the new thread to finish...
# it is what it is

# %%
import threading 
import time 


def worker():
    time.sleep(2)
    print("DONE")

#these are individual independent thread
t1= threading.Thread(target=worker)
t1.start()
t2= threading.Thread(target=worker)
t2.start()
t3= threading.Thread(target=worker)
t3.start()
t4= threading.Thread(target=worker)
t4.start()
t5= threading.Thread(target=worker)
t5.start()
t6= threading.Thread(target=worker)
t6.start()
# Out:
# DONEDONE
# DONE
# DONE
# DONE
# DONE

# %%
import time
from concurrent.futures import ThreadPoolExecutor

def worker(number):
    print(f"calculating the result for number {number}")
    time.sleep(2)
    return number ** 2

pool = ThreadPoolExecutor(4)
work1 = pool.submit(worker, 7)
work2 = pool.submit(worker, 8)
work3 = pool.submit(worker, 9)
work4 = pool.submit(worker, 10)
work5 = pool.submit(worker, 11)
work6 = pool.submit(worker, 12)

#this function kills the asynchronous behavior or multithreading 
# it's basically awaiting the result so you cannot run this to get the result
# firslty it wait for the task done then it will print the result function 
# firstly work3 will complete then it will print the result 
print(work2.result())

# time.sleep(5)
print(work3.done()) #either true or false

#anything which comes afterwards in main thread print immediately
#we don't wait for the task to finish
print("hello world")
# Out:
# calculating the result for number 7
# calculating the result for number 8
# calculating the result for number 9
# calculating the result for number 10
# False
# hello world
# calculating the result for number 11
# calculating the result for number 12
